# %% [markdown]
# Este es nuetro primer notebook, En él vamos a hacer un "Hola Mundo", un par d operaciones aritmeticas simples y vamos a rminar con u gráfico como el ejemplo dado en esta primera clase.

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# Una Suma:

# %%
a = 5
b = 8
x = a + b
print("x = ", x)
# Out:
# x =  13

# %% [markdown]
# Una multiplicacion:

# %%
y = a * b
print("y = ", y)
# Out:
# y =  40

# %% [markdown]
# y por ultimo un gráfico:

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 10
sigma = 100

datos_azar = np.random.normal(mu, sigma, 300)
plt.hist(datos_azar,30, density=True, alpha=0.6, color='g')
plt.xlabel('Numeros')
plt.ylabel('Frecuencia')
print(datos_azar)
# Out:
# [ 1.83991340e+02  6.13193195e+01 -5.93250030e+01 -1.80451356e+02
#   5.83061044e+01  3.56093970e+01  1.57027237e+02 -7.47037460e+01
#  -1.24991517e+02  6.75905619e+01  1.14372945e+01 -7.47874729e+01
#  -1.84742072e+01  1.53622525e+02 -4.76463808e+01  2.97974470e+02
#   1.96890016e+01 -4.59346005e+01  2.39289537e+01 -2.31042379e+01
#   8.39273062e+01  8.92894833e+01 -6.09556194e+01 -4.79165426e+01
#  -1.95968488e+02 -4.18652024e+01 -1.16676515e+01  9.63371154e+01
#   2.75088524e+00  6.77436153e+01 -5.44187568e+01  2.31129463e+01
#   3.71761317e+01 -2.80103389e+02  1.89502999e+02  9.67683972e+01
#   1.02993869e+02  3.22256155e+01 -8.98467723e+01 -2.29597755e+02
#  -1.17787928e+00 -2.00688223e+01 -6.94550689e+00 -7.28269911e+01
#   1.07302718e+02 -6.09247423e+01  1.70235139e+01 -7.74155264e+01
#  -9.32272596e+01 -2.12964910e+02  1.22573384e-01 -2.11233460e+01
#  -5.49869369e+01 -9.19985993e+01 -2.88356638e+01  6.98732636e+00
# ...
