# %% [markdown]
# # clase 19 de Marzo : Limpieza
# en la clase de hoy vamos a tratar el tema de la limpieza de los datos, en base al mismo conjunto de datos de la sesión anterior

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://dmontero.org/mineria/datasets/2.2.4%20Food_Preference.csv'
data_frame = pd.read_csv(url)
data_frame.head()
# Out:
#                      Timestamp Participant_ID  Gender Nationality  Age  \
# 0  2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1  2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2  2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3  2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4  2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
#
#                Food              Juice Dessert
# 0  Traditional food        Fresh Juice   Maybe
# 1      Western Food  Carbonated drinks     Yes
# 2      Western Food        Fresh Juice   Maybe
# 3  Traditional food        Fresh Juice   Maybe
# 4  Traditional food        Fresh Juice   Maybe

# %% [markdown]
# Quiero que miremos la nacionalidad:

# %%
nacionalidades = data_frame['Nationality'].unique()
print(nacionalidades.shape)
print(nacionalidades)
# Out:
# (27,)
# ['Indian' 'Pakistani ' 'Tanzanian' 'Indonesia' 'Muslim' 'Pakistan'
#  'Maldivian ' 'MY' 'Malaysian' 'Malaysian ' 'Indonesian ' 'Maldivian'
#  'MALAYSIAN' 'Malaysia ' 'Pakistani' 'Canadian' 'Nigerian ' 'Algerian '
#  'Korean ' 'Seychellois' 'Indonesain' 'Indonesian' 'Malaysia' 'Japan'
#  'China' 'Mauritian' 'Yemen']

# %% [markdown]
# Voy a tomar el enfoque más simple: reemplazar el texto erroneo por el texto correcto.
# Esto lo voy a hacer en una copia de los datos para no "dañar" el original.

# %%
df_copia = data_frame.copy()
# reemplazamos
df_copia['Nationality'] = df_copia['Nationality'].replace('Pakistani ', 'Pakistani')
df_copia['Nationality'] = df_copia['Nationality'].replace('Pakistan', 'Pakistani')
df_copia['Nationality'] = df_copia['Nationality'].replace('Indonesian ', 'Indonesian')
df_copia['Nationality'] = df_copia['Nationality'].replace('Indonesain', 'Indonesian')
df_copia['Nationality'] = df_copia['Nationality'].replace('Indonesia', 'Indonesian')
df_copia['Nationality'] = df_copia['Nationality'].replace('Maldivian ', 'Maldivian')
df_copia['Nationality'] = df_copia['Nationality'].replace('Malaysian ', 'Malaysian')
df_copia['Nationality'] = df_copia['Nationality'].replace('MALAYSIAN', 'Malaysian')
df_copia['Nationality'] = df_copia['Nationality'].replace('Malaysia ', 'Malaysian')
df_copia['Nationality'] = df_copia['Nationality'].replace('Malaysia', 'Malaysian')
df_copia['Nationality'] = df_copia['Nationality'].replace('MY', 'Malaysian')
# mostramos las nacionalidades
nacionalidades_limpias = df_copia['Nationality'].unique()
print(nacionalidades_limpias.shape)
print(nacionalidades_limpias)
# Out:
# (16,)
# ['Indian' 'Pakistani' 'Tanzanian' 'Indonesian' 'Muslim' 'Maldivian'
#  'Malaysian' 'Canadian' 'Nigerian ' 'Algerian ' 'Korean ' 'Seychellois'
#  'Japan' 'China' 'Mauritian' 'Yemen']

# %% [markdown]
# Veamos cuantos datos hay por nacionalidad...

# %%
df_copia['Nationality'].value_counts()
# Out:
# Indian         241
# Malaysian       16
# Indonesian      10
# Pakistani        6
# Maldivian        3
# Japan            2
# Tanzanian        1
# Muslim           1
# Canadian         1
# Nigerian         1
# Algerian         1
# Korean           1
# Seychellois      1
# China            1
# Mauritian        1
# Yemen            1
# Name: Nationality, dtype: int64

# %% [markdown]
# Tengo un problema: muslim (musulmán) no es una nacionalidad, sino la pertenencia a una religión.
# En la India un 25% aprox de la población es musulmana, asi que voy a atribuir el dato de muslim a 'Indian'

# %%
df_copia['Nationality'] = df_copia['Nationality'].replace('Muslim', 'Indian')
# mostramos las nacionalidades
nacionalidades_limpias = df_copia['Nationality'].unique()
print(nacionalidades_limpias.shape)
print(nacionalidades_limpias)
df_copia['Nationality'].value_counts()
# Out:
# (15,)
# ['Indian' 'Pakistani' 'Tanzanian' 'Indonesian' 'Maldivian' 'Malaysian'
#  'Canadian' 'Nigerian ' 'Algerian ' 'Korean ' 'Seychellois' 'Japan'
#  'China' 'Mauritian' 'Yemen']
# Indian         242
# Malaysian       16
# Indonesian      10
# Pakistani        6
# Maldivian        3
# Japan            2
# Tanzanian        1
# Canadian         1
# Nigerian         1
# Algerian         1
# Korean           1
# Seychellois      1
# China            1
# Mauritian        1
# Yemen            1
# Name: Nationality, dtype: int64

# %% [markdown]
# Cuando tengo el data frame con los datos limpios, deberia guardar el resultado:

# %%
df_copia.to_csv('s3_FoodPref_clean.csv')

# %% [markdown]
# **Problema! Lo guardamos en una maquina cloud a la que despues no tendremos acceso**
# Deberia guardarla en otra parte... en Drive!

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df_copia.to_csv('/content/drive/My Drive/s3_FoodPref_clean.csv')

# %% [markdown]
# De la misma forma en que puedo escribir al drive, puedo cargar datos desde ahi mismo.

# %%
df_limpio = pd.read_csv('/content/drive/My Drive/s3_FoodPref_clean.csv')
df_limpio.head()
# Out:
#    Unnamed: 0                    Timestamp Participant_ID  Gender Nationality  \
# 0           0  2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian
# 1           1  2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian
# 2           2  2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian
# 3           3  2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian
# 4           4  2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian
#
#    Age              Food              Juice Dessert
# 0   24  Traditional food        Fresh Juice   Maybe
# 1   22      Western Food  Carbonated drinks     Yes
# 2   31      Western Food        Fresh Juice   Maybe
# 3   25  Traditional food        Fresh Juice   Maybe
# 4   27  Traditional food        Fresh Juice   Maybe
